# %%
# !git clone https://github.com/axelv/Pytorch-UNet.git
# Out:
# Cloning into 'Pytorch-UNet'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 216 (delta 2), reused 6 (delta 2), pack-reused 210
# Receiving objects: 100% (216/216), 47.30 MiB | 38.17 MiB/s, done.
# Resolving deltas: 100% (113/113), done.

# %%
# %cd Pytorch-UNet/
# Out:
# /content/Pytorch-UNet

# %%
# !git pull
# Out:
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 4), reused 4 (delta 2), pack-reused 0
# Unpacking objects: 100% (6/6), done.
# From https://github.com/axelv/Pytorch-UNet
#    f42dd01..8ac8f81  master     -> origin/master
# Updating f42dd01..8ac8f81
# Fast-forward
#  main.py | 5 ++++-
#  1 file changed, 4 insertions(+), 1 deletion(-)

# %%
from torch import nn, optim, cuda
from main import main, init
from unet_small.unet_model import UNetSmall
cuda.is_available()
# Out:
# True

# %%
main()
# Out:
#   0%|          | 0/600 [00:00<?, ?it/s]
# Epoch 0/24
# ----------
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/upsampling.py:129: UserWarning: nn.Upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.{} is deprecated. Use nn.functional.interpolate instead.".format(self.name))
#   0%|          | 0/100 [00:00<?, ?it/s]
# train Loss: 0.0397
#   0%|          | 0/600 [00:00<?, ?it/s]
# val Loss: 0.0108
# Epoch 1/24
# ----------
#   0%|          | 0/100 [00:00<?, ?it/s]
# train Loss: 0.0133
#   0%|          | 0/600 [00:00<?, ?it/s]
# val Loss: 0.0095
# Epoch 2/24
# ----------
#   0%|          | 0/100 [00:00<?, ?it/s]
# train Loss: 0.0142
#   0%|          | 0/600 [00:00<?, ?it/s]
# val Loss: 0.0336
# Epoch 3/24
# ----------
#   0%|          | 0/100 [00:00<?, ?it/s]
# train Loss: 0.0112
#   0%|          | 0/600 [00:00<?, ?it/s]
# val Loss: 0.0266
# Epoch 4/24
# ----------
#   0%|          | 0/100 [00:00<?, ?it/s]
# train Loss: 0.0108
# ...

# %%
import plotly.plotly as py

from plotly.offline import iplot, plot
from plotly.offline import init_notebook_mode, iplot

from plotly import graph_objs as go
init_notebook_mode(connected=False)

from IPython.display import display

def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import joblib
import numpy as np
result = joblib.load("validation_results.joblib")

# %%
labels = np.concatenate(result['labels'])
losses = np.concatenate(result['mse'])

# %%
configure_plotly_browser_state()
traces = []

for i in range(10):
  print("Label %d - mean loss: %.5f" % (i, np.mean(losses[labels == i])))

  traces.append(go.Histogram(
      x=losses[labels == i],
      opacity=0.75,
      histnorm='probability'
  ))

layout = go.Layout(barmode='overlay')
fig = go.Figure(data=traces, layout=layout)
iplot(fig)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# Label 0 - mean loss: 0.03413
# Label 1 - mean loss: 0.03636
# Label 2 - mean loss: 0.03498
# Label 3 - mean loss: 0.03607
# Label 4 - mean loss: 0.03710
# Label 5 - mean loss: 0.03556
# Label 6 - mean loss: 0.03419
# Label 7 - mean loss: 0.03448
# Label 8 - mean loss: 0.03623
# Label 9 - mean loss: 0.03705
# ...
